# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from kmodes.kprototypes import KPrototypes
from kmodes.kmodes import KModes

# %%
df = pd.read_csv("segmentation_data.csv")
df.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
df.tail()
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0

# %%
df.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
df_temp = df[['ID','Age','Income']]
df_temp
# Out:
#              ID  Age  Income
# 0     100000001   67  124670
# 1     100000002   22  150773
# 2     100000003   49   89210
# 3     100000004   45  171565
# 4     100000005   53  149031
# ...         ...  ...     ...
# 1995  100001996   47  123525
# 1996  100001997   27  117744
# 1997  100001998   31   86400
# 1998  100001999   24   97968
# 1999  100002000   25   68416
#
# [2000 rows x 3 columns]

# %%
scaler = MinMaxScaler()
scaler.fit(df[['Age']])
df['Age'] = scaler.transform(df[['Age']])

scaler.fit(df[['Income']])
df['Income'] = scaler.transform(df[['Income']])

# %%
df = df.drop(['ID'],axis =1)

# %%
mark_array = df.values
mark_array[:,2] = mark_array[:,2].astype(float)
mark_array[:,4] = mark_array[:,4].astype(float)

# %% [markdown]
# # Model Kurma

# %%
kproto = KPrototypes(n_clusters = 10, verbose=2,max_iter=20)
clusters = kproto.fit_predict(mark_array, categorical=[0, 1, 3, 5, 6])

print(kproto.cluster_centroids_)

len(kproto.cluster_centroids_)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 720, ncost: 164.03639873697713
# Run: 1, iteration: 2/20, moves: 61, ncost: 163.8884171638477
# Run: 1, iteration: 3/20, moves: 9, ncost: 163.8743501809091
# Run: 1, iteration: 4/20, moves: 5, ncost: 163.87131638852864
# Run: 1, iteration: 5/20, moves: 0, ncost: 163.87131638852864
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1009, ncost: 176.0578519724213
# Run: 2, iteration: 2/20, moves: 185, ncost: 173.51471428532528
# Run: 2, iteration: 3/20, moves: 127, ncost: 172.31762675979508
# Run: 2, iteration: 4/20, moves: 45, ncost: 172.05537055787633
# Run: 2, iteration: 5/20, moves: 22, ncost: 171.9417793660481
# Run: 2, iteration: 6/20, moves: 18, ncost: 171.87777617711419
# Run: 2, iteration: 7/20, moves: 5, ncost: 171.8715670730825
# Run: 2, iteration: 8/20, moves: 1, ncost: 171.87146375962035
# Run: 2, iteration: 9/20, moves: 0, ncost: 171.87146375962035
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 875, ncost: 188.8850207325252
# Run: 3, iteration: 2/20, moves: 287, ncost: 181.9405693893768
# Run: 3, iteration: 3/20, moves: 97, ncost: 181.3325708400553
# Run: 3, iteration: 4/20, moves: 25, ncost: 181.26490368841186
# Run: 3, iteration: 5/20, moves: 7, ncost: 181.26031010369925
# Run: 3, iteration: 6/20, moves: 0, ncost: 181.26031010369925
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 842, ncost: 160.40198392359596
# Run: 4, iteration: 2/20, moves: 254, ncost: 157.68065325352381
# Run: 4, iteration: 3/20, moves: 47, ncost: 157.56799346502973
# Run: 4, iteration: 4/20, moves: 6, ncost: 157.56290579350375
# Run: 4, iteration: 5/20, moves: 0, ncost: 157.56290579350375
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 762, ncost: 183.86112249955875
# Run: 5, iteration: 2/20, moves: 371, ncost: 170.8022706384079
# Run: 5, iteration: 3/20, moves: 208, ncost: 170.25977353915053
# Run: 5, iteration: 4/20, moves: 19, ncost: 170.2144563367005
# Run: 5, iteration: 5/20, moves: 14, ncost: 170.1778592091361
# Run: 5, iteration: 6/20, moves: 10, ncost: 170.16773345447976
# Run: 5, iteration: 7/20, moves: 9, ncost: 170.1580909453288
# Run: 5, iteration: 8/20, moves: 5, ncost: 170.15213077750542
# Run: 5, iteration: 9/20, moves: 8, ncost: 170.1449163995838
# Run: 5, iteration: 10/20, moves: 6, ncost: 170.1343409764759
# Run: 5, iteration: 11/20, moves: 4, ncost: 170.1183191744478
# Run: 5, iteration: 12/20, moves: 10, ncost: 169.99553420752224
# Run: 5, iteration: 13/20, moves: 6, ncost: 169.97853011500982
# Run: 5, iteration: 14/20, moves: 3, ncost: 169.97100542657822
# Run: 5, iteration: 15/20, moves: 0, ncost: 169.97100542657822
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 794, ncost: 162.73772108168765
# Run: 6, iteration: 2/20, moves: 174, ncost: 161.88591930958333
# Run: 6, iteration: 3/20, moves: 101, ncost: 160.61081465587282
# Run: 6, iteration: 4/20, moves: 60, ncost: 160.38902008146405
# Run: 6, iteration: 5/20, moves: 11, ncost: 160.38089632646074
# Run: 6, iteration: 6/20, moves: 0, ncost: 160.38089632646074
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 661, ncost: 164.86088250258396
# Run: 7, iteration: 2/20, moves: 193, ncost: 161.4981447504514
# Run: 7, iteration: 3/20, moves: 45, ncost: 161.4098809298868
# Run: 7, iteration: 4/20, moves: 7, ncost: 161.39199624955754
# Run: 7, iteration: 5/20, moves: 4, ncost: 161.39045093736328
# Run: 7, iteration: 6/20, moves: 0, ncost: 161.39045093736328
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 884, ncost: 183.97708037392007
# Run: 8, iteration: 2/20, moves: 278, ncost: 180.77992853174018
# Run: 8, iteration: 3/20, moves: 115, ncost: 180.24994511570486
# Run: 8, iteration: 4/20, moves: 57, ncost: 179.88290230523504
# Run: 8, iteration: 5/20, moves: 78, ncost: 179.0015325373481
# Run: 8, iteration: 6/20, moves: 65, ncost: 178.28897681406224
# Run: 8, iteration: 7/20, moves: 86, ncost: 172.56187567705084
# Run: 8, iteration: 8/20, moves: 96, ncost: 171.90727853471464
# Run: 8, iteration: 9/20, moves: 17, ncost: 171.88452575408158
# Run: 8, iteration: 10/20, moves: 6, ncost: 171.8740641220452
# Run: 8, iteration: 11/20, moves: 1, ncost: 171.87388801888784
# Run: 8, iteration: 12/20, moves: 0, ncost: 171.87388801888784
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 708, ncost: 193.35679597829835
# Run: 9, iteration: 2/20, moves: 223, ncost: 181.17076436987438
# Run: 9, iteration: 3/20, moves: 178, ncost: 180.2710288505516
# Run: 9, iteration: 4/20, moves: 39, ncost: 180.20567275431924
# Run: 9, iteration: 5/20, moves: 7, ncost: 180.19725067438154
# Run: 9, iteration: 6/20, moves: 4, ncost: 180.19524756839618
# Run: 9, iteration: 7/20, moves: 1, ncost: 180.19491219321208
# Run: 9, iteration: 8/20, moves: 4, ncost: 180.1928280629149
# Run: 9, iteration: 9/20, moves: 0, ncost: 180.1928280629149
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 847, ncost: 167.6191506683027
# Run: 10, iteration: 2/20, moves: 165, ncost: 166.4032482156692
# Run: 10, iteration: 3/20, moves: 32, ncost: 166.34062384606636
# Run: 10, iteration: 4/20, moves: 8, ncost: 166.33161121582424
# Run: 10, iteration: 5/20, moves: 1, ncost: 166.33145488431794
# Run: 10, iteration: 6/20, moves: 0, ncost: 166.33145488431794
# Best run was number 4
# [[0.167472   0.33577434 0.         0.         0.         1.
#   1.        ]
#  [0.21810629 0.18652268 1.         1.         1.         0.
#   0.        ]
#  [0.19562334 0.29350875 1.         1.         1.         1.
#   0.        ]
#  [0.70287065 0.43261635 0.         1.         2.         1.
#   1.        ]
#  [0.14469236 0.16640911 0.         0.         0.         0.
#   0.        ]
#  [0.35445898 0.54000583 0.         0.         1.         2.
#   2.        ]
#  [0.40337385 0.3537031  0.         0.         1.         1.
#   1.        ]
#  [0.43985021 0.22194513 0.         0.         1.         0.
#   0.        ]
#  [0.16991245 0.31494031 1.         1.         1.         1.
#   1.        ]
#  [0.19133142 0.33462894 1.         1.         1.         1.
#   2.        ]]
# 10

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)
df['cluster'] = cluster_dict

df[['ID','Age','Income']] = df_temp

# %%
df[df['cluster'] == 0].head(10)
# Out:
#     Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 17    0               0   25          0  157434           1                2
# 19    0               0   31          0  144657           1                1
# 31    0               0   27          0  120131           1                1
# 32    0               0   30          0  162745           1                2
# 36    0               0   31          0  143385           1                2
# 39    0               0   24          0   92542           1                1
# 40    0               0   30          0  163329           2                1
# 52    0               0   25          0   92058           1                2
# 53    0               0   31          0  117158           1                0
# 63    0               0   25          0  227385           1                2
#
#     cluster         ID
# 17        0  100000018
# 19        0  100000020
# 31        0  100000032
# 32        0  100000033
# 36        0  100000037
# 39        0  100000040
# 40        0  100000041
# 52        0  100000053
# 53        0  100000054
# 63        0  100000064

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]
df4 = df[df.cluster == 3]
df5 = df[df.cluster == 4]
df6 = df[df.cluster == 6]
df7 = df[df.cluster == 7]
df8 = df[df.cluster == 8]
df9 = df[df.cluster == 9]
df10 = df[df.cluster == 10]

plt.figure(figsize=(15,15))
plt.xlabel('Age')
plt.ylabel('Income')

plt.scatter(df1.Age, df1['Income'],color='green', alpha = 0.4)
plt.scatter(df2.Age, df2['Income'],color='red', alpha = 0.4)
plt.scatter(df3.Age, df3['Income'],color='gray', alpha = 0.4)
plt.scatter(df4.Age, df4['Income'],color='orange', alpha = 0.4)
plt.scatter(df5.Age, df5['Income'],color='yellow', alpha = 0.4)
plt.scatter(df6.Age, df6['Income'],color='cyan', alpha = 0.4)
plt.scatter(df7.Age, df7['Income'],color='magenta', alpha = 0.4)
plt.scatter(df8.Age, df8['Income'],color='black', alpha = 0.4)
plt.scatter(df9.Age, df9['Income'],color='purple', alpha = 0.4)
plt.scatter(df10.Age, df10['Income'],color='blue', alpha = 0.4)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
